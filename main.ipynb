# %%
import requests
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv("weather_data.csv")

# %%
df
# Out:
#             Ville  Température actuelle  Température ressentie  \
# 0           Paris                  7.41                   3.89
# 1       Marseille                 15.40                  14.09
# 2            Lyon                  5.10                   2.87
# 3        Toulouse                 10.91                  10.04
# 4            Nice                  9.03                   7.86
# 5          Nantes                  7.78                   4.76
# 6      Strasbourg                  7.15                   3.56
# 7     Montpellier                 16.54                  15.35
# 8        Bordeaux                 12.15                  11.14
# 9           Lille                  9.27                   5.94
# 10         Rennes                  5.02                   2.46
# 11          Reims                  7.87                   3.70
# 12       Le Havre                  8.51                   5.67
# 13  Saint-Etienne                  5.62                   2.05
# ...
